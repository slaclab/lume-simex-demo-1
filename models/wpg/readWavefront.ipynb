# %%
# This example read the WPG simulation result of the TXI beamline taken from the case:
# Modeling KB as imperfect KB (as thin lens?)

# %%
from SimEx.Analysis.XFELPhotonAnalysis import XFELPhotonAnalysis
import h5py
# Out:
# initializing ocelot...
#
# WARNING: esther_execute could not be imported. This is most probably due to Esther not being installed or not found. Expect RunTimeErrors when attempting to run the EstherPhotonMatterInteractor.backengine().

# %%
input_path="g4_0kev_bl2.h5"

# %%
TXIbeam = XFELPhotonAnalysis(input_path=input_path)
# Out:
#  Start initialization.
#
#  Loading wavefront from g4_0kev_bl2.h5.
#  ... done.
#
#  Getting intensities.
#  ... done.
#  Data dimensions =  (416, 832, 1)
#
#  Masking NANs.
#  ... done.

# %%
TXIbeam.plotIntensityMap()
# Out:
#  Plotting intensity map.
# R-space

# %% [markdown]
# [WPG hdf5 format Glossary definition](https://wpg.readthedocs.io/en/latest/glossary.html?highlight=hdf5#glossary-definition)

# %%
with h5py.File(input_path, 'r') as h5:
    print (h5['params/photonEnergy'][...],'eV')
# Out:
# 4000.0 eV
